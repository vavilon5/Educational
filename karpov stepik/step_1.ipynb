# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ## step 1.4

# %%
st_per = pd.read_csv('StudentsPerformance.csv')

# %%
st_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
st_per.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
st_per.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
st_per.shape
# Out:
# (1000, 8)

# %%
st_per.groupby('gender').aggregate({'writing score': 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
st_per.iloc[0:3]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
st_per.iloc[[0, 3, 10], [1, -2, 5]]
# Out:
#    race/ethnicity  reading score  math score
# 0         group B             72          72
# 3         group A             57          47
# 10        group C             54          58

# %%
new_per = st_per.iloc[[0, 3, 4, 7, 8]]

# %%
new_per.index = ['a','b','c','d','e']

# %%
new_per
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# a  female        group B           bachelor's degree      standard
# b    male        group A          associate's degree  free/reduced
# c    male        group C                some college      standard
# d    male        group B                some college  free/reduced
# e    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# a                    none          72             72             74
# b                    none          47             57             44
# c                    none          76             78             75
# d                    none          40             43             39
# e               completed          64             64             67

# %%
new_per.loc[['a', 'c', 'd'], ['gender', 'math score']]
# Out:
#    gender  math score
# a  female          72
# c    male          76
# d    male          40

# %%
type(new_per.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %%
ser_1 = pd.Series([1,2,3], index = ['a', 'b', 'c'])
ser_2 = pd.Series([4,5,6], index = ['a', 'b', 'c'])

# %%
pd.DataFrame({'col1' : ser_1, 'col2': ser_2})
# Out:
#    col1  col2
# a     1     4
# b     2     5
# c     3     6

# %%
titanic = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %% [markdown]
# ## step 1.5

# %%
st_per
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
st_per.loc[st_per.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
writing_mean = st_per['writing score'].mean()

# %%
st_per.loc[st_per['writing score'] > writing_mean]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
st_per['lunch'].value_counts(normalize=True) #st_per.lunch.value_counts(normalize=True)
# Out:
# standard        0.645
# free/reduced    0.355
# Name: lunch, dtype: float64

# %%
lunch_score = st_per.loc[range(0,1000), ['lunch', 'math score', 'reading score', 'writing score']]
standart_lunch = lunch_score[lunch_score.lunch=='standard']
reduced_lunch = lunch_score[lunch_score.lunch=='free/reduced']

# %%
standart_lunch.describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
reduced_lunch.describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
st_per = st_per.rename(columns = 
                       {'writing score' : 'writing_score',
                        'reading score' : 'reading_score',
                        'math score' : 'math_score',
                        'test preparation course' : 'test_preparation_course',
                        'parental level of education' : 'parental_level_of_education',})

# %%
st_per.query("writing_score > @writing_mean & gender == 'male'")
# Out:
#     gender race/ethnicity parental_level_of_education         lunch  \
# 4     male        group C                some college      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# ..     ...            ...                         ...           ...
# 971   male        group C            some high school      standard
# 981   male        group D            some high school      standard
# 982   male        group B            some high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 4                      none          76             78             75
# ...

# %%
st_per.filter(like='score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## step 1.6

# %%
st_per.groupby('gender', as_index=False).aggregate({'math_score': 'mean', 'reading_score': 'mean'})
# Out:
#    gender  math_score  reading_score
# 0  female   63.633205      72.608108
# 1    male   68.728216      65.473029

# %%
mean_scores = st_per.groupby(['gender', 'race/ethnicity']).aggregate({'math_score': 'mean', 'reading_score': 'mean'})
mean_scores
# Out:
#                        math_score  reading_score
# gender race/ethnicity
# female group A          58.527778      69.000000
#        group B          61.403846      71.076923
#        group C          62.033333      71.944444
#        group D          65.248062      74.046512
#        group E          70.811594      75.840580
# male   group A          63.735849      61.735849
#        group B          65.930233      62.848837
#        group C          67.611511      65.424460
#        group D          69.413534      66.135338
#        group E          76.746479      70.295775

# %%
mean_scores.index
# Out:
# MultiIndex([('female', 'group A'),
#             ('female', 'group B'),
#             ('female', 'group C'),
#             ('female', 'group D'),
#             ('female', 'group E'),
#             (  'male', 'group A'),
#             (  'male', 'group B'),
#             (  'male', 'group C'),
#             (  'male', 'group D'),
#             (  'male', 'group E')],
#            names=['gender', 'race/ethnicity'])

# %%
st_per.groupby(['gender', 'race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %%
st_per.sort_values(['gender', 'math_score'], ascending=False) \
    .groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
st_per['total_score'] = st_per.math_score + st_per.reading_score + st_per.writing_score
st_per
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
st_per = st_per.assign(total_score_log = np.log(st_per.total_score))
st_per
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
st_per.drop(['total_score'], axis=1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
dota = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota.dtypes
# Out:
# Unnamed: 0         int64
# attack_type       object
# id                 int64
# legs               int64
# localized_name    object
# name              object
# primary_attr      object
# roles             object
# dtype: object

# %%
dota.groupby('legs', as_index=False).aggregate({'legs':'count'})
# Out:
#    legs
# 0    11
# 1    95
# 2     7
# 3     3
# 4     1

# %%
dota.groupby(['attack_type', 'primary_attr']).aggregate({'id':'count'}).sort_values('id', ascending=False)
#dota.filter(items=['attack_type','primary_attr']).mode()
# Out:
#                           id
# attack_type primary_attr
# Ranged      int           40
# Melee       str           35
#             agi           19
# Ranged      agi           18
#             str            3
# Melee       int            2

# %%
lupa_pupa = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')

# %%
lupa_pupa.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
# Press L to have nummeration
lupa_pupa.groupby(['Type','Executor'], as_index=False).aggregate({'Salary':'mean'})
# Out:
#    Type Executor      Salary
# 0     A    Loopa   58.000000
# 1     A     Pupa  160.833333
# 2     B    Loopa  145.166667
# 3     B     Pupa   77.000000
# 4     C    Loopa  154.333333
# 5     C     Pupa   74.500000
# 6     D    Loopa  137.714286
# 7     D     Pupa  146.500000
# 8     E    Loopa  164.000000
# 9     E     Pupa  131.200000
# 10    F    Loopa  238.000000
# 11    F     Pupa  136.250000

# %%
concentrations = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
concentrations
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
mean_concentrations = concentrations.groupby('genus', as_index=False).aggregate({
    'sucrose':'mean',
    'alanin':'mean',
    'citrate':'mean',
    'glucose':'mean',
    'oleic_acid':'mean'
})
#concentrations.groupby(['genus']).mean(numeric_only=True)

# %%
concentrations.groupby('genus').agg(['min', 'mean', 'max']).loc['Fucus', 'alanin'].round(2)
# Out:
# C:\Users\vasil\AppData\Local\Temp\ipykernel_11184\3257143798.py:1: FutureWarning: ['species', 'group'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   concentrations.groupby('genus').agg(['min', 'mean', 'max']).loc['Fucus', 'alanin'].round(2)
# min     0.35
# mean    3.57
# max     6.64
# Name: Fucus, dtype: float64

# %%
concentrations.groupby('group', as_index=False).aggregate({'citrate': 'var'}).round(2)
# Out:
#    group  citrate
# 0  brown     5.47
# 1  green     3.95
# 2    red      NaN

# %% [markdown]
# ## step 1.7 - visualization

# %%
st_per.math_score.hist()
# Out:
# <AxesSubplot: >

# %%
st_per.plot.scatter(x='math_score', y='reading_score')
# Out:
# <AxesSubplot: xlabel='math_score', ylabel='reading_score'>

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', data = st_per, fit_reg=False)
ax.set_xlabels('Math')
ax.set_ylabels('Reading')

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot: >

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot: >

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot: ylabel='income'>

# %%
df.income.plot()
# Out:
# <AxesSubplot: >

# %%
df['income'].plot()
# Out:
# <AxesSubplot: >

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
new = pd.read_csv("dataset_209770_6.txt", sep=" ")
new
# Out:
#               x            y
# 0    202.256665  1002.189332
# 1    289.327473    96.548708
# 2    201.511027  1005.074027
# 3   1421.969709  1301.358083
# 4   1090.570397   291.444915
# ..          ...          ...
# 65  1100.743922   304.575603
# 66  1110.397001   303.766030
# 67   304.968440   109.746393
# 68   410.888719   196.810087
# 69   601.889567   703.415019
#
# [70 rows x 2 columns]

# %%
ax = sns.lmplot(x='x', y='y', data = new)

# %%
genome = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv')

# %%
genome.iloc[:, 1:]
# Out:
#    species0  species1  species2  species3  species4
# 0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(genome.iloc[:, 1:])
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota = pd.read_csv('dota_hero_stats.csv')

# %%
dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
(dota.roles.str.count(',')+1).mode()
# Out:
# 0    4
# Name: roles, dtype: int64

# %%
iris = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', sep=',')

# %%
iris = iris.iloc[:, 1:]

# %%
iris.sample(7, random_state=60)
# Out:
#     sepal length  sepal width  petal length  petal width  species
# 69           5.6          2.5           3.9          1.1        1
# 71           6.1          2.8           4.0          1.3        1
# 97           6.2          2.9           4.3          1.3        1
# 42           4.4          3.2           1.3          0.2        0
# 73           6.1          2.8           4.7          1.2        1
# 35           5.0          3.2           1.2          0.2        0
# 67           5.8          2.7           4.1          1.0        1

# %%
for column in iris.iloc[:, :-1]:
    sns.displot(data=iris, x=f"{column}", kde=True)

# %%
sns.violinplot(y=iris['petal length'])
# Out:
# <AxesSubplot: ylabel='petal length'>

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# ## step 1.8 - practice

# %%
my_data = pd.DataFrame({'type': ['A','A','B','B'], 'value': [10, 14, 12, 23]})

# %%
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')

# %%
my_stat.sample(7, random_state=60)
# Out:
#      V1    V2 V3   V4
# 249  -2  13.0  B  0.0
# 405  -3  13.0  A  1.0
# 40    0  11.0  A  1.0
# 165  -4  12.0  B -1.0
# 473  -1  10.0  B  1.0
# 265  -2  12.0  A  2.0
# 203   0  11.0  B  0.0

# %%
subset_1 = my_stat.iloc[:10, [0,2]]
subset_2 = my_stat[~my_stat.index.isin([0,4])].iloc[:, [1, 3]]

# %%
subset_2.head()
# Out:
#      V2   V4
# 1   7.0  1.0
# 2  11.0  0.0
# 3  11.0  2.0
# 5  11.0  0.0
# 6   9.0  2.0

# %%
subset_1 = my_stat.loc[(my_stat['V1'] > 0) & (my_stat['V3'] == 'A')]
# subset_1
subset_2 = my_stat.loc[(my_stat['V2'] != 10) | (my_stat['V4'] >= 1)]
subset_2
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
my_stat = my_stat.assign(V5 = my_stat.V1 + my_stat.V4, V6 = np.log(my_stat.V2))

# %%
my_stat.sample(7, random_state=60)
# Out:
#      V1    V2 V3   V4   V5        V6
# 249  -2  13.0  B  0.0 -2.0  2.564949
# 405  -3  13.0  A  1.0 -2.0  2.564949
# 40    0  11.0  A  1.0  1.0  2.397895
# 165  -4  12.0  B -1.0 -5.0  2.484907
# 473  -1  10.0  B  1.0  0.0  2.302585
# 265  -2  12.0  A  2.0  0.0  2.484907
# 203   0  11.0  B  0.0  0.0  2.397895

# %%
my_stat = my_stat.rename(columns=
                         {'V1': 'session_value',
                          'V2': 'group',
                          'V3': 'time',
                          'V4': 'n_users'})

# %%
my_stat.sample(7, random_state=60)
# Out:
#      session_value  group time  n_users   V5        V6
# 249             -2   13.0    B      0.0 -2.0  2.564949
# 405             -3   13.0    A      1.0 -2.0  2.564949
# 40               0   11.0    A      1.0  1.0  2.397895
# 165             -4   12.0    B     -1.0 -5.0  2.484907
# 473             -1   10.0    B      1.0  0.0  2.302585
# 265             -2   12.0    A      2.0  0.0  2.484907
# 203              0   11.0    B      0.0  0.0  2.397895

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')

# %%
my_stat.sample(7, random_state=60)
# Out:
#    session_value  time group  n_users
# 5            3.0     8     A        8
# 8            0.0     8     B      -11
# 7            0.0     9     A        4
# 4            2.0    10     B        9
# 9            0.0     9     A      -20
# 0            0.0    12     B        9
# 3            2.0     9     B        3

# %%
~my_stat.session_value.isnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: session_value, dtype: bool

# %%
my_stat.session_value = my_stat.session_value.fillna(0)
medi = my_stat.n_users[my_stat.n_users > 0].median()
my_stat.n_users = my_stat.n_users.mask(my_stat.n_users < 0, medi)

# my_stat.session_value.fillna(0, inplace=True)
# my_stat.loc[my_stat.n_users < 0, 'n_users'] = my_stat[my_stat.n_users >= 0].n_users.median()

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A        5
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B        5
# 9            0.0     9     A        5

# %%
my_stat.sample(7, random_state=60)
# Out:
#    session_value  time group  n_users
# 5            3.0     8     A        8
# 8            0.0     8     B        5
# 7            0.0     9     A        4
# 4            2.0    10     B        9
# 9            0.0     9     A        5
# 0            0.0    12     B        9
# 3            2.0     9     B        3

# %%
mean_session_value_data = my_stat.groupby('group', as_index=False) \
                                 .agg({'session_value':'mean'}) \
                                 .rename(columns={'session_value': 'mean_session_value'})

# mean_session_value_data = my_stat.groupby("group",as_index=False).session_value.agg({'mean_session_value':'mean'})

# %%
mean_session_value_data
# Out:
#   group  mean_session_value
# 0     A                 0.8
# 1     B                 0.8

# %% [markdown]
# ## step 1.10 - подготовка данных

# %%
events_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/event_data_train.zip')

# %%
events_data.sample(7, random_state=60)
# Out:
#          step_id   timestamp           action  user_id
# 1529267    32089  1476629504  started_attempt     6668
# 927558     32206  1453546361           viewed    17816
# 377918     32181  1436102179           viewed     3899
# 1553818    32927  1477216224           viewed    10391
# 2579916    33902  1507082014           viewed    26654
# 1469739    32191  1475519804       discovered    25547
# 1418459    32219  1474500604           viewed    17056

# %%
events_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3480703 entries, 0 to 3480702
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   step_id    int64
#  1   timestamp  int64
#  2   action     object
#  3   user_id    int64
# dtypes: int64(3), object(1)
# memory usage: 106.2+ MB

# %%
events_data.action.unique()
# Out:
# array(['viewed', 'passed', 'discovered', 'started_attempt'], dtype=object)

# %%
events_data['date'] = pd.to_datetime(events_data.timestamp, unit='s') # unit='s' подразумевает, что timestamp в секундах

# %%
events_data.sample(7, random_state=60)
# Out:
#          step_id   timestamp           action  user_id                date
# 1529267    32089  1476629504  started_attempt     6668 2016-10-16 14:51:44
# 927558     32206  1453546361           viewed    17816 2016-01-23 10:52:41
# 377918     32181  1436102179           viewed     3899 2015-07-05 13:16:19
# 1553818    32927  1477216224           viewed    10391 2016-10-23 09:50:24
# 2579916    33902  1507082014           viewed    26654 2017-10-04 01:53:34
# 1469739    32191  1475519804       discovered    25547 2016-10-03 18:36:44
# 1418459    32219  1474500604           viewed    17056 2016-09-21 23:30:04

# %%
events_data.date.max()
# Out:
# Timestamp('2018-05-19 23:33:31')

# %%
events_data['day'] = events_data.date.dt.date # достать день

# %%
events_data.sample(7, random_state=60)
# Out:
#          step_id   timestamp           action  user_id                date  \
# 1529267    32089  1476629504  started_attempt     6668 2016-10-16 14:51:44
# 927558     32206  1453546361           viewed    17816 2016-01-23 10:52:41
# 377918     32181  1436102179           viewed     3899 2015-07-05 13:16:19
# 1553818    32927  1477216224           viewed    10391 2016-10-23 09:50:24
# 2579916    33902  1507082014           viewed    26654 2017-10-04 01:53:34
# 1469739    32191  1475519804       discovered    25547 2016-10-03 18:36:44
# 1418459    32219  1474500604           viewed    17056 2016-09-21 23:30:04
#
#                 day
# 1529267  2016-10-16
# 927558   2016-01-23
# 377918   2015-07-05
# 1553818  2016-10-23
# 2579916  2017-10-04
# 1469739  2016-10-03
# 1418459  2016-09-21

# %%
events_data.groupby('day') \
    .user_id.nunique().sample(7, random_state=60)
# Out:
# day
# 2016-08-20     62
# 2017-09-16    113
# 2016-10-06    190
# 2016-12-17     71
# 2017-11-24    127
# 2018-04-17    169
# 2017-01-21     65
# Name: user_id, dtype: int64

# %%
sns.set(rc={'figure.figsize': (9, 6)})

# %%
events_data.groupby('day') \
    .user_id.nunique().plot()
# Out:
# <AxesSubplot: xlabel='day'>

# %%
events_data[events_data.action == 'passed'] \
    .groupby('user_id', as_index=False) \
    .agg({'step_id': 'count'}) \
    .rename(columns={'step_id': 'passed_steps'}).sample(7, random_state=60) # число не уникальных степов, решенных юзером

# Теряем юзеров, которые не прошли ни один степ
# Out:
#        user_id  passed_steps
# 13227    20576             2
# 14475    22523             1
# 4603      7027            51
# 1012      1533            85
# 14077    21910            45
# 2422      3667             1
# 10291    15963           142

# %%
events_data[events_data.action == 'passed'] \
    .groupby('user_id', as_index=False) \
    .agg({'step_id': 'count'}) \
    .rename(columns={'step_id': 'passed_steps'}).passed_steps.hist()
# Out:
# <AxesSubplot: >

# %%
# Правильное решение

events_data.pivot_table(index='user_id', 
                        columns='action', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index().sample(7, random_state=60)
# Out:
# action  user_id  discovered  passed  started_attempt  viewed
# 4016       5563         198     198              109     480
# 17793     24786          10      10                2      39
# 2650       3624          25      24                9      44
# 6845       9496           1       1                0       1
# 18913     26349           1       0                1       2
# 13462     18736           1       1                0       1
# 6273       8692           2       2                0       3

# %%
events_data.pivot_table(index='user_id', 
                        columns='action', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index().discovered.hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## step 1.11

# %%
submissions_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/submissions_data_train.zip')

# %%
submissions_data.sample(7, random_state=60)
# Out:
#         step_id   timestamp submission_status  user_id
# 289746    32031  1490224661             wrong    19811
# 438350   120745  1518642265           correct    16121
# 187826    33350  1468927590             wrong    18502
# 294541    31988  1492003091           correct    22431
# 230601    31972  1475759526             wrong     2542
# 213704    31978  1473693028             wrong    17047
# 356736    33332  1504881526             wrong     9470

# %%
submissions_data['date'] = pd.to_datetime(submissions_data.timestamp, unit='s') # unit='s' подразумевает, что timestamp в секундах
submissions_data['day'] = submissions_data.date.dt.date # достать день

# %%
submissions_data.sample(7, random_state=60)
# Out:
#         step_id   timestamp submission_status  user_id                date  \
# 289746    32031  1490224661             wrong    19811 2017-03-22 23:17:41
# 438350   120745  1518642265           correct    16121 2018-02-14 21:04:25
# 187826    33350  1468927590             wrong    18502 2016-07-19 11:26:30
# 294541    31988  1492003091           correct    22431 2017-04-12 13:18:11
# 230601    31972  1475759526             wrong     2542 2016-10-06 13:12:06
# 213704    31978  1473693028             wrong    17047 2016-09-12 15:10:28
# 356736    33332  1504881526             wrong     9470 2017-09-08 14:38:46
#
#                day
# 289746  2017-03-22
# 438350  2018-02-14
# 187826  2016-07-19
# 294541  2017-04-12
# 230601  2016-10-06
# 213704  2016-09-12
# 356736  2017-09-08

# %%
submissions_data[submissions_data.submission_status == 'correct'] \
    .groupby('user_id') \
    .agg({'submission_status': 'count'}) \
    .sort_values(by='submission_status', ascending=False).head(1)

# user_id Анатолия Карпова
# Out:
#          submission_status
# user_id
# 1046                   421

# %%
user_scores = submissions_data.pivot_table(index='user_id', 
                        columns='submission_status', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index()

# %%
user_scores.sample(7, random_state=60)
# Out:
# submission_status  user_id  correct  wrong
# 8598                 23254       13     16
# 6680                 17861       54     41
# 8681                 23460        8      3
# 4646                 12422       10      5
# 9575                 25861        2      0
# 9925                 26772        9      5
# 5155                 13773       73    110

# %%
events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
    .groupby('user_id')['timestamp'].apply(list) \
    .apply(np.diff).sample(7, random_state=60)
# Out:
# user_id
# 5563     [1111942, 803088, 84546, 24441921, 78535, 9150...
# 24786                                             [524507]
# 3624                          [475178, 34717997, 10426506]
# 9496                                                    []
# 26349                                                   []
# 18736                                                   []
# 8692                                                    []
# Name: timestamp, dtype: object

# %%
gap_data = events_data[['user_id', 'day', 'timestamp']].drop_duplicates(subset=['user_id', 'day']) \
    .groupby('user_id')['timestamp'].apply(list) \
    .apply(np.diff).values
gap_data
# Out:
# array([array([], dtype=int32), array([4843602]),
#        array([6899249,  182484,   93710, 2768870,  171400,   78712]), ...,
#        array([   86128,   136759,    94899,  1422583, 14347289,   505061,
#                  98252,    57019])                                       ,
#        array([1567990]), array([], dtype=int32)], dtype=object)

# %%
gap_data = pd.Series(np.concatenate(gap_data, axis=0)) / (24 * 60 * 60)

# %%
gap_data
# Out:
# 0         56.060208
# 1         79.852419
# 2          2.112083
# 3          1.084606
# 4         32.047106
#             ...
# 97867    166.056586
# 97868      5.845613
# 97869      1.137176
# 97870      0.659942
# 97871     18.148032
# Length: 97872, dtype: float64

# %%
gap_data[gap_data < 200].hist()
# Out:
# <AxesSubplot: >

# %%
gap_data.quantile(0.9) # 10% юзеров возвращаются после перерыва в 18 дней
# Out:
# 18.325995370370403

# %%
events_data.tail()
# Out:
#          step_id   timestamp      action  user_id                date  \
# 3480698    33375  1526772685      viewed    11677 2018-05-19 23:31:25
# 3480699    32815  1526772750      viewed     5198 2018-05-19 23:32:30
# 3480700    32815  1526772750  discovered     5198 2018-05-19 23:32:30
# 3480701    32815  1526772750      passed     5198 2018-05-19 23:32:30
# 3480702    33892  1526772811      viewed    18526 2018-05-19 23:33:31
#
#                 day
# 3480698  2018-05-19
# 3480699  2018-05-19
# 3480700  2018-05-19
# 3480701  2018-05-19
# 3480702  2018-05-19

# %%
now = 1526772811
drop_out_threshold = 30*24*60*60

# %%
users_data = events_data.groupby('user_id', as_index=False) \
    .agg({'timestamp': 'max'}).rename(columns={'timestamp': 'last_timestamp'})

# %%
users_data.head()
# Out:
#    user_id  last_timestamp
# 0        1      1472827464
# 1        2      1519226966
# 2        3      1444581588
# 3        5      1499859939
# 4        7      1521634660

# %%
users_data['is_gone_user'] = (now - users_data.last_timestamp) > drop_out_threshold # бросил ли юзер курс

# %%
users_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user
# 0        1      1472827464          True
# 1        2      1519226966          True
# 2        3      1444581588          True
# 3        5      1499859939          True
# 4        7      1521634660          True

# %%
users_data = users_data.merge(user_scores, on='user_id', how='outer').fillna(0)

# %%
users_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user  correct  wrong
# 0        1      1472827464          True      0.0    0.0
# 1        2      1519226966          True      2.0    0.0
# 2        3      1444581588          True     29.0   23.0
# 3        5      1499859939          True      2.0    2.0
# 4        7      1521634660          True      0.0    0.0

# %%
users_events_data = events_data.pivot_table(index='user_id', 
                        columns='action', 
                        values='step_id', 
                        aggfunc='count', 
                        fill_value=0).reset_index()

# %%
users_events_data.head()
# Out:
# action  user_id  discovered  passed  started_attempt  viewed
# 0             1           1       0                0       1
# 1             2           9       9                2      10
# 2             3          91      87               30     192
# 3             5          11      11                4      12
# 4             7           1       1                0       1

# %%
users_data = users_data.merge(users_events_data, how='outer')

# %%
users_days = events_data.groupby('user_id').day.nunique().to_frame().reset_index()

# %%
users_days.head()
# Out:
#    user_id  day
# 0        1    1
# 1        2    2
# 2        3    7
# 3        5    2
# 4        7    1

# %%
users_data = users_data.merge(users_days, how='outer')

# %%
users_data.head()
# Out:
#    user_id  last_timestamp  is_gone_user  correct  wrong  discovered  passed  \
# 0        1      1472827464          True      0.0    0.0           1       0
# 1        2      1519226966          True      2.0    0.0           9       9
# 2        3      1444581588          True     29.0   23.0          91      87
# 3        5      1499859939          True      2.0    2.0          11      11
# 4        7      1521634660          True      0.0    0.0           1       1
#
#    started_attempt  viewed  day
# 0                0       1    1
# 1                2      10    2
# 2               30     192    7
# 3                4      12    2
# 4                0       1    1

# %%
users_data.user_id.nunique() == events_data.user_id.nunique() # Проверка на потерю пользователей из сырых данных
# Out:
# True

# %%
users_data['passed_course'] = users_data.passed > 170

# %%
users_data.sample(7, random_state=60)
# Out:
#        user_id  last_timestamp  is_gone_user  correct  wrong  discovered  \
# 4016      5563      1513850008          True     77.0   55.0         198
# 17793    24786      1437500186          True      2.0    0.0          10
# 2650      3624      1516609804          True      8.0    1.0          25
# 6845      9496      1519743653          True      0.0    0.0           1
# 18913    26349      1436427806          True      0.0    1.0           1
# 13462    18736      1441729125          True      0.0    0.0           1
# 6273      8692      1438869418          True      0.0    0.0           2
#
#        passed  started_attempt  viewed  day  passed_course
# 4016      198              109     480   34           True
# 17793      10                2      39    2          False
# 2650       24                9      44    4          False
# 6845        1                0       1    1          False
# 18913       0                1       2    1          False
# ...
